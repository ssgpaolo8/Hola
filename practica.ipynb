# %% [markdown]
# ## Practicando ando
# ### Nivel pollo

# %%
import pandas as pd
datos = pd.DataFrame ({"manzanas": [3, 2], "peras" : [1,4]}, index = ["Juan", "Pedro"])
datos
# Out:
#        manzanas  peras
# Juan          3      1
# Pedro         2      4

# %%
datos.plot.bar()
# Out:
# <Axes: >

# %%
datos.plot.line()
# Out:
# <Axes: >

# %%
x=1

# %%
f = True
